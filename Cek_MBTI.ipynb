# %%
import sys

def display(tipe_kepribadian):
    print(f"Tipe Kepribadian kamu adalah -> {tipe_kepribadian}")
def run():
    questions: list = [
        """
Question 1:
a.Lebih memilih berkomunikasi dengan menulis
b.Lebih memilih berkomunikasi dengan bicara
""",
        """
Question 2:
a.Menemukan dan mengembangkan ide dengan merenungkan
b.Menemukan dan mengembangkan ide dengan mendiskusikannya
""",
        """
Question 3:
a.Berorientasi pada dunia internal (memori, pemikiran, ide)
b.Berorientasi pada dunia eksternal (kegiatan, orang)
""",
        """
Question 4:
a.Fokus pada sedikit hobi namun mendalam
b.Fokus pada banyak hobi secara luas dan umum
""",
        """
Question 5:
a.Tertutup dan mandiri
b.Sosial dan Ekspresif
""",
        """
Question 6:
a.Pertemuan dengan orang lain dan aktivitas sosial melelahkan
b.Pertemuan dengan orang lain dan aktivitas sosial membuat bersemangat
""",
        """
Question 7:
a.Beraktifitas sendirian di rumah menyenangkan
b.Beraktifitas sendirian di rumah membosankan
""",
        """
Question 8:
a.Berinisiatif bila situasi memaksa atau berhubungan dengan kepentingan sendiri
b.Berinisiatif tinggi hampir dalam berbagai hal meskipun tidak berhubungan dengan diri sendiri
""",
        """
Question 9:
a.Lebih memilih tempat yang tenang dan pribadi untuk berkonsentrasi
b.Lebih memilih tempat yang ramai dan banyak interaksi/aktivitas
""",
        """
Question 10:
a.Berpikir secara matang sebelum bertindak
b.Berani bertindak tanpa terlalu lama memikir
""",
        """
Question 11:
a.Menyimpan semangat dalam hati
b.Mengekspresikan semangat
""",
        """
Question 12:
a.Mencari kesempatan untuk berkomunikasi secara perorangan
b.Memilih berkomunikasi pada sekelompok orang
""",
        """
Question 13:
a.Lebih suka komunikasi tidak langsung (telp, surat, e-mail)
b.Lebih suka komunikasi langsung
""",
        """
Question 14:
a.Membangun ide dengan matang baru membicarakannya
b.Membangun ide pada saat berbicara
""",
        """
Question 15:
a.Berhati-hari, penuh pertimbangan, kaku
b.Spontan, Easy Going, Fleksibel
""",
        """
Question 16:
a.Bergerak dari detail ke gambaran umum sebagai kesimpulan akhir
b.Bergerak dari gambaran umum baru ke detail
""",
        """
Question 17:
a.Berbicara mengenai masalah yang dihadapi hari ini dan langkah-langkah praktis mengatasinya
b.Berbicara mengenai visi visi depan dan konsep-konsep mengenai visi tersebut
""",
        """
Question 18:
a.Menggunakan pengalaman sebagai pedoman
b.Menggunakan imajinasi dan perenungan sebagai pedoman
""",
        """
Question 19:
a.SOP sangat membantu
b.SOP sangat membosankan
""",
        """
Question 20:
a.Prosedural dan tradisional
b.Bebas dan Dinamis
""",
        """
Question 21:
a.Memilih fakta lebih penting daripada ide inspiratif
b.Memilih ide inspiratif lebih penting daripada fakta
""",
        """
Question 22:
a.Kontinuitas dan stabilitas lebih diutamakan
b.Perubahan dan variasi lebih diutamakan
""",
        """
Question 23:
a.Bertindak step by step dengan timeframe yang jelas
b.Bertindak dengan semangat tanpa menggunakan frame
""",
        """
Question 24:
a.Menarik kesimpulan dengan lama dan hati-hati
b.Menarik kesimpulan dengan cepat sesuai naluri
""",
        """
Question 25:
a.Mengklarifikasi ide dan teori sebelum dipraktekkan
b.Memahami ide dan teori saat mempraktekkannya langsung
""",
        """
Question 26:
a.Berfokus pada masa kini (apa yang bisa diperbaiki sekarang)
b.Berfokus pada masa depan (apa yang mungkin dicapai di masa depan)
""",
        """
Question 27:
a.Secara konsisten mengamati dan mengingat detail
b.Mengamati dan mengingat detail hanya bila berhubungan dengan pola
""",
        """
Question 28:
a.Praktis
b.Konseptual
""",
        """
Question 29:
a.Menggunakan ketrampilan yang sudah dikuasai
b.Menyukai tantangan untuk menguasai ketrampilan baru
""",
        """
Question 30:
a.Memilih cara yang sudah ada dan sudah terbukti
b.Memilih cara yang unik dan belum dipraktekkan orang lain
""",
        """
Question 31:
a.Obyektif
b.Subyektif
""",
        """
Question 32:
a.Diyakinkan dengan penjelasan yang masuk akal
b.Diyakinkan dengan penjelasan yang menyentuh perasaan
""",
        """
Question 33:
a.Berorientasi tugas dan job description
b.Berorientasi pada manusia dan hubungan
""",
        """
Question 34:
a.Mengambil keputusan berdasar logika dan aturan main
b.Membangun ide pada saat berbicara
""",
        """
Question 35:
a.Mengemukakan tujuan dan sasaran lebih dahulu
b.Mengemukakan kesepakatan terlebih dahulu
""",
        """
Question 36:
a.Menganalisa
b.Berempati
""",
        """
Question 37:
a.Menghargai seseorang karena skill dan faktor tenis
b.Menghargai seseorang karena sifat dan perilakunya
""",
        """
Question 38:
a.Melibatkan perasaan itu tidak profesional
b.Terlalu kaku pada peraturan dan pekerjaan itu kejam
""",
        """
Question 39:
a.Yang penting tujuan tercapai
b.Yang penting situasi harmonis terjaga
""",
        """
Question 40:
a.Mempertanyakan
b.Mengakomodasi
""",
        """
Question 41:
a.Sering dianggap keras kepala
b.Sering dianggap terlalu memihak
""",
        """
Question 42:
a.Bersemangat saat mengkritik dan menemukan kesalahan
b.Bersemangat saat menolong orang keluar dari kesalahan dan meluruskan
""",
        """
Question 43:
a.Standar harus ditegakkan di atasa segalanya (itu menunjukkan kehormatan dan harga diri)
b.Perasaan manusia lebih penting dari sekedar standar (yang adalah benda mati)
""",
        """
Question 44:
a.Menuntut perlakuan yang adil dan sama pada semua orang
b.Menuntut perlakuan khusus sesuai karakteristik masing-masing orang
""",
        """
Question 45:
a.Mementingkan sebab akibat
b.Mementingkan nilai-nilai personal
""",
        """
Question 46:
a.Terencana dan memiliki deadline jelas
b.Spontan, fleksibel, tidak diikat waktu
""",
        """
Question 47:
a.Tidak menyukai hal-hal yang bersifat mendadak dan di luar perencanaan
b.Perubahan mendadak tidak jadi masalah
""",
        """
Question 48:
a.Aturan, jadwal dan target akan sangat membantu dan memperjelas tindakan
b.Aturan, jadwal, dan target sangat mengikat dan membebani
""",
        """
Question 49:
a.Berorientasi pada hasil
b.Berorientasi pada proses
""",
        """
Question 50:
a.Mengatur orang lain dengan tata tertib agar tujuan tercapai
b.Membiarkan orang lain bertindak bebas asalkan tujuan tercapai
""",
        """
Question 51:
a.Fokus pada target dan mengabaikan hal-hal baru
b.Memperhatikan hal-hal baru dan siap menyesuaikan diri serta mengubah target
""",
        """
Question 52:
a.Berpegang teguh pada pendirian
b.Pendirian masih bisa berubah tergantung situasi nantinya
""",
        """
Question 53:
a.Merasa tenang bila semua sudah diputuskan
b.Merasa nyaman bila situasi tetap terbuka terhadap pilihan-pilihan lain
""",
        """
Question 54:
a.Ketidakpastian membuat bingung dan meresahkan
b.Ketidak pastian itu seru, menegangkan dan membuat hati lebih senang
""",
        """
Question 55:
a.Situasi last minute membuat bersemangat dan memunculkan potensi
b.Situasi last minute sangat menyiksa, membuat stress, dan merupakan kesalahan
""",
        """
Question 56:
a.Perubahan adalah musuh
b.Perubahan adalah semangat hidup
""",
        """
Question 57:
a.Bertindak sesuai apa yang sudah direncanakan
b.Bertindak sesuai situasi dan kondisi yang terjadi saat itu
""",
        """
Question 58:
a.Hidup harus sudah diatur dari awal
b.Hidup seharusnya mengalir sesuai kondisi
""",
        """
Question 59:
a.Daftar dan checklist adalah panduan penting
b.Daftar dan checklist adalah tugas dan beban
""",
        """
Question 60:
a.Puas ketika mampu menjalankan semuanya sesuai rencana
b.Puas ketika mampu beradaptasi dengan momentum yang terjadi
""",
    ]

    hitung_a: int = 0
    hitung_b: int = 0
    Kepribadian: str = ''
    hitung = 0

    for question in questions:
        answer = ''
        while not (answer == 'A' or answer == 'B'):
            hitung_a = 0
            hitung_b = 0
            try:
                answer = input(question).upper()
                if not (answer == 'A' or answer == 'B'):
                    raise ValueError("Invalid input")
            except ValueError as error:
                print(error)
            else:
                if answer == 'A':
                    hitung_a = hitung_a + 1
                if answer == 'B':
                    hitung_b = hitung_b + 1
                hitung = hitung + 1

        if hitung == 15:
            if hitung_a > hitung_b:
                Kepribadian = Kepribadian + 'I '
            else:
                Kepribadian = Kepribadian + 'E '
        else:
            if hitung == 30:
                if hitung_a > hitung_b:
                    Kepribadian = Kepribadian + 'S '
                else:
                    Kepribadian = Kepribadian + 'N '
            else:
                if hitung == 45:
                    if hitung_a > hitung_b:
                        Kepribadian = Kepribadian + 'T '
                    else:
                        Kepribadian = Kepribadian + 'F '
                else:
                    if hitung == 60:
                        if hitung_a > hitung_b:
                            Kepribadian = Kepribadian + 'J '
                        else:
                            Kepribadian = Kepribadian + 'P '

    display(Kepribadian)


def exit_application():
    print("Exiting application...")
    sys.exit(0)


def main():
    user_input = input("""
    Selamat Datang di Meyers Briggs Personality Test/MBTI
    Tekan 1 untuk memulai tes
    Tekan 2 untuk keluar dari aplikasi -> """)
    try:
        if not (user_input == "1" or user_input == "2"):
            raise ValueError("Invalid input")
    except ValueError as error:
        print(error)
    else:
        switcher = {
            "1": run,
            "2": exit_application
        }
        return switcher.get(user_input)()


if __name__ == "__main__":
    main()

# %%
import sys

def display(tipe_kepribadian):
    print(f"Tipe Kepribadian kamu adalah -> {tipe_kepribadian}")
def tampilkan(karakteristik):
    print(f"Karakteristik kamu adalah sebagai berikut: {karakteristik}")
def run():
    questions: list = [
        """
Question 1:
a.Lebih memilih berkomunikasi dengan menulis
b.Lebih memilih berkomunikasi dengan bicara
""",
        """
Question 2:

a.Menemukan dan mengembangkan ide dengan merenungkan
b.Menemukan dan mengembangkan ide dengan mendiskusikannya
""",
        """
Question 3:
a.Berorientasi pada dunia internal (memori, pemikiran, ide)
b.Berorientasi pada dunia eksternal (kegiatan, orang)
""",
        """
Question 4:
a.Fokus pada sedikit hobi namun mendalam
b.Fokus pada banyak hobi secara luas dan umum
""",
        """
Question 5:
a.Tertutup dan mandiri
b.Sosial dan Ekspresif
""",
        """
Question 6:
a.Pertemuan dengan orang lain dan aktivitas sosial melelahkan
b.Pertemuan dengan orang lain dan aktivitas sosial membuat bersemangat
""",
        """
Question 7:
a.Beraktifitas sendirian di rumah menyenangkan
b.Beraktifitas sendirian di rumah membosankan
""",
        """
Question 8:
a.Berinisiatif bila situasi memaksa atau berhubungan dengan kepentingan sendiri
b.Berinisiatif tinggi hampir dalam berbagai hal meskipun tidak berhubungan dengan diri sendiri
""",
        """
Question 9:
a.Lebih memilih tempat yang tenang dan pribadi untuk berkonsentrasi
b.Lebih memilih tempat yang ramai dan banyak interaksi/aktivitas
""",
        """
Question 10:
a.Berpikir secara matang sebelum bertindak
b.Berani bertindak tanpa terlalu lama memikir
""",
        """
Question 11:
a.Menyimpan semangat dalam hati
b.Mengekspresikan semangat
""",
        """
Question 12:
a.Mencari kesempatan untuk berkomunikasi secara perorangan
b.Memilih berkomunikasi pada sekelompok orang
""",
        """
Question 13:
a.Lebih suka komunikasi tidak langsung (telp, surat, e-mail)
b.Lebih suka komunikasi langsung
""",
        """
Question 14:
a.Membangun ide dengan matang baru membicarakannya
b.Membangun ide pada saat berbicara
""",
        """
Question 15:
a.Berhati-hari, penuh pertimbangan, kaku
b.Spontan, Easy Going, Fleksibel
""",
        """
Question 16:
a.Bergerak dari detail ke gambaran umum sebagai kesimpulan akhir
b.Bergerak dari gambaran umum baru ke detail
""",
        """
Question 17:
a.Berbicara mengenai masalah yang dihadapi hari ini dan langkah-langkah praktis mengatasinya
b.Berbicara mengenai visi visi depan dan konsep-konsep mengenai visi tersebut
""",
        """
Question 18:
a.Menggunakan pengalaman sebagai pedoman
b.Menggunakan imajinasi dan perenungan sebagai pedoman
""",
        """
Question 19:
a.SOP sangat membantu
b.SOP sangat membosankan
""",
        """
Question 20:
a.Prosedural dan tradisional
b.Bebas dan Dinamis
""",
        """
Question 21:
a.Memilih fakta lebih penting daripada ide inspiratif
b.Memilih ide inspiratif lebih penting daripada fakta
""",
        """
Question 22:
a.Kontinuitas dan stabilitas lebih diutamakan
b.Perubahan dan variasi lebih diutamakan
""",
        """
Question 23:
a.Bertindak step by step dengan timeframe yang jelas
b.Bertindak dengan semangat tanpa menggunakan frame
""",
        """
Question 24:
a.Menarik kesimpulan dengan lama dan hati-hati
b.Menarik kesimpulan dengan cepat sesuai naluri
""",
        """
Question 25:
a.Mengklarifikasi ide dan teori sebelum dipraktekkan
b.Memahami ide dan teori saat mempraktekkannya langsung
""",
        """
Question 26:
a.Berfokus pada masa kini (apa yang bisa diperbaiki sekarang)
b.Berfokus pada masa depan (apa yang mungkin dicapai di masa depan)
""",
        """
Question 27:
a.Secara konsisten mengamati dan mengingat detail
b.Mengamati dan mengingat detail hanya bila berhubungan dengan pola
""",
        """
Question 28:
a.Praktis
b.Konseptual
""",
        """
Question 29:
a.Menggunakan ketrampilan yang sudah dikuasai
b.Menyukai tantangan untuk menguasai ketrampilan baru
""",
        """
Question 30:
a.Memilih cara yang sudah ada dan sudah terbukti
b.Memilih cara yang unik dan belum dipraktekkan orang lain
""",
        """
Question 31:
a.Obyektif
b.Subyektif
""",
        """
Question 32:
a.Diyakinkan dengan penjelasan yang masuk akal
b.Diyakinkan dengan penjelasan yang menyentuh perasaan
""",
        """
Question 33:
a.Berorientasi tugas dan job description
b.Berorientasi pada manusia dan hubungan
""",
        """
Question 34:
a.Mengambil keputusan berdasar logika dan aturan main
b.Membangun ide pada saat berbicara
""",
        """
Question 35:
a.Mengemukakan tujuan dan sasaran lebih dahulu
b.Mengemukakan kesepakatan terlebih dahulu
""",
        """
Question 36:
a.Menganalisa
b.Berempati
""",
        """
Question 37:
a.Menghargai seseorang karena skill dan faktor tenis
b.Menghargai seseorang karena sifat dan perilakunya
""",
        """
Question 38:
a.Melibatkan perasaan itu tidak profesional
b.Terlalu kaku pada peraturan dan pekerjaan itu kejam
""",
        """
Question 39:
a.Yang penting tujuan tercapai
b.Yang penting situasi harmonis terjaga
""",
        """
Question 40:
a.Mempertanyakan
b.Mengakomodasi
""",
        """
Question 41:
a.Sering dianggap keras kepala
b.Sering dianggap terlalu memihak
""",
        """
Question 42:
a.Bersemangat saat mengkritik dan menemukan kesalahan
b.Bersemangat saat menolong orang keluar dari kesalahan dan meluruskan
""",
        """
Question 43:
a.Standar harus ditegakkan di atasa segalanya (itu menunjukkan kehormatan dan harga diri)
b.Perasaan manusia lebih penting dari sekedar standar (yang adalah benda mati)
""",
        """
Question 44:
a.Menuntut perlakuan yang adil dan sama pada semua orang
b.Menuntut perlakuan khusus sesuai karakteristik masing-masing orang
""",
        """
Question 45:
a.Mementingkan sebab akibat
b.Mementingkan nilai-nilai personal
""",
        """
Question 46:
a.Terencana dan memiliki deadline jelas
b.Spontan, fleksibel, tidak diikat waktu
""",
        """
Question 47:
a.Tidak menyukai hal-hal yang bersifat mendadak dan di luar perencanaan
b.Perubahan mendadak tidak jadi masalah
""",
        """
Question 48:
a.Aturan, jadwal dan target akan sangat membantu dan memperjelas tindakan
b.Aturan, jadwal, dan target sangat mengikat dan membebani
""",
        """
Question 49:
a.Berorientasi pada hasil
b.Berorientasi pada proses
""",
        """
Question 50:
a.Mengatur orang lain dengan tata tertib agar tujuan tercapai
b.Membiarkan orang lain bertindak bebas asalkan tujuan tercapai
""",
        """
Question 51:
a.Fokus pada target dan mengabaikan hal-hal baru
b.Memperhatikan hal-hal baru dan siap menyesuaikan diri serta mengubah target
""",
        """
Question 52:
a.Berpegang teguh pada pendirian
b.Pendirian masih bisa berubah tergantung situasi nantinya
""",
        """
Question 53:
a.Merasa tenang bila semua sudah diputuskan
b.Merasa nyaman bila situasi tetap terbuka terhadap pilihan-pilihan lain
""",
        """
Question 54:
a.Ketidakpastian membuat bingung dan meresahkan
b.Ketidak pastian itu seru, menegangkan dan membuat hati lebih senang
""",
        """
Question 55:
a.Situasi last minute membuat bersemangat dan memunculkan potensi
b.Situasi last minute sangat menyiksa, membuat stress, dan merupakan kesalahan
""",
        """
Question 56:
a.Perubahan adalah musuh
b.Perubahan adalah semangat hidup
""",
        """
Question 57:
a.Bertindak sesuai apa yang sudah direncanakan
b.Bertindak sesuai situasi dan kondisi yang terjadi saat itu
""",
        """
Question 58:
a.Hidup harus sudah diatur dari awal
b.Hidup seharusnya mengalir sesuai kondisi
""",
        """
Question 59:
a.Daftar dan checklist adalah panduan penting
b.Daftar dan checklist adalah tugas dan beban
""",
        """
Question 60:
a.Puas ketika mampu menjalankan semuanya sesuai rencana
b.Puas ketika mampu beradaptasi dengan momentum yang terjadi
""",
    ]

    hitung_a: int = 0
    hitung_b: int = 0
    Kepribadian: str = ''
    karakteristik: str=''
    hitung = 0

    for question in questions:
        answer = ''
        while not (answer == 'A' or answer == 'B'):
            hitung_a = 0
            hitung_b = 0
            try:
                answer = input(question).upper()
                if not (answer == 'A' or answer == 'B'):
                    raise ValueError("Invalid input")
            except ValueError as error:
                print(error)
            else:
                if answer == 'A':
                    hitung_a = hitung_a + 1
                if answer == 'B':
                    hitung_b = hitung_b + 1
                hitung = hitung + 1

        if hitung == 15:
            if hitung_a > hitung_b:
                Kepribadian = Kepribadian + 'I '
                karakteristik=karakteristik+"""\n Kamu orang yang lebih suka bekerja sendiri atau di dalam kelompok kecil\n
                cenderung memikirkan ide kamu terlebih dahulu dengan matang\n
                kamu juga fokus dalam mengerjakan satu tugas dalam satu waktu.\n"""
            else:
                Kepribadian = Kepribadian + 'E '
                karakteristik=karakteristik + """\n Kamu orang yang mendapatkan energi ketika bertemu dengan orang-orang,\n
                mampu mengerjakan berbagai jenis tugas,\n
                dapat mengambil langkah cepat dan sangat hebat dalam multitasking.\n"""
        else:
            if hitung == 30:
                if hitung_a > hitung_b:
                    Kepribadian = Kepribadian + 'S '
                    karakteristik=karakteristik+"""\n kamu adalah orang yang realitas sehingga fokus akan fakta dan detail.\n
                    kamu cenderung menerapkan akal sehat dan mengambil langkah berdasarkan pengalamanmu dengan solusi-solusi yang sudah terjamin berhasil sebelumnya.\n"""
                else:
                    Kepribadian = Kepribadian + 'N '
                    karakteristik=karakteristik+"""\n kamu adalah seseorang yang idealis dan lebih memilih untuk fokus terhadap kemungkinan-kemungkinan dan gambaran besar\n
                    kamu juga mudah melihat pola, nilai dari inovasi dan mengemukakan ide-ide kreatif terhadap solusi sebuah masalah.\n"""
            else:
                if hitung == 45:
                    if hitung_a > hitung_b:
                        Kepribadian = Kepribadian + 'T '
                        karakteristik=karakteristik+"""\n kamu cenderung membuat keputusan dengan menggunakan analisis logika\n
                        objektif antara pro dan kontra serta menghargai kejujuran, konsistensi, dan keadilan.\n"""
                    else:
                        Kepribadian = Kepribadian + 'F '
                        karakteristik=karakteristik+"\n kamu cenderung sensitif dan memiliki sifat kerjasama sehingga biasanya kamu memutuskan berdasarkan pendapat diri sendiri dengan juga mempertimbangkan bagaimana perasaan orang lain dari aksi yang kamu lakukan."
                else:
                    if hitung == 60:
                        if hitung_a > hitung_b:
                            Kepribadian = Kepribadian + 'J '
                            karakteristik=karakteristik+"""\n cenderung terorganisir dan terencana\n
                            sangat suka merancang dan melekat terhadap rencana\n
                            dan sangat nyaman untuk mematuhi aturan."""
                        else:
                            Kepribadian = Kepribadian + 'P '
                            karakteristik=karakteristik+ """\n lebih memilih untuk terbuka terhadap pilihan-pilihan\n
                            sangat suka untuk bertindak secara spontan dan juga fleksibel dalam membuat perencanaan. """

    display(Kepribadian)
    tampilkan(karakteristik)


def exit_application():
    print("Exiting application...")
    sys.exit(0)


def main():
    user_input = input("""
    Selamat Datang di Meyers Briggs Personality Test/MBTI
    Tekan 1 untuk memulai tes
    Tekan 2 untuk keluar dari aplikasi -> """)
    try:
        if not (user_input == "1" or user_input == "2"):
            raise ValueError("Invalid input")
    except ValueError as error:
        print(error)
    else:
        switcher = {
            "1": run,
            "2": exit_application
        }
        return switcher.get(user_input)()


if __name__ == "__main__":
    main()
